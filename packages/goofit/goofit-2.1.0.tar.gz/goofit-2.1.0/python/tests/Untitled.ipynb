# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal, norm

# %%
rnorm = norm(1.5, 2.5);
rnorm.pdf(1.2)
# Out:
# 0.15843208471746245

# %%
rnorm.pdf(7.2)
# Out:
# 0.0118618339389365

# %%
bin_centers_x = np.linspace(-5,10,101) + .15/2
bin_centers_y = np.linspace(-5,10,101) + .15/2
X,Y = np.meshgrid(bin_centers_x, bin_centers_y)

# %%
cov = np.array([[2.5, 0],[0, .5]])

# %%
mnorm = multivariate_normal([1.5, -1],cov)
vv = mnorm.pdf(np.stack([X,Y],-1))

# %%
for i in range(0,101,20):
    for j in range(0,101,20):
        print(i, j, X[i,j], Y[i,j], vv[i,j])
# Out:
# 0 0 -4.925 -4.925 7.53698529533e-12
# 0 20 -1.925 -4.925 2.77893287162e-09
# 0 40 1.075 -4.925 2.79961498365e-08
# 0 60 4.075 -4.925 7.70652208898e-09
# 0 80 7.075 -4.925 5.79640084441e-11
# 0 100 10.075 -4.925 1.19123723447e-14
# 20 0 -4.925 -1.925 1.57102240832e-05
# 20 20 -1.925 -1.925 0.00579245632235
# 20 40 1.075 -1.925 0.0583556647869
# 20 60 4.075 -1.925 0.0160636095436
# 20 80 7.075 -1.925 0.000120821193851
# 20 100 10.075 -1.925 2.48303574394e-08
# 40 0 -4.925 1.075 4.98731061164e-07
# 40 20 -1.925 1.075 0.000183885212145
# 40 40 1.075 1.075 0.00185253771493
# 40 60 4.075 1.075 0.000509949507491
# 40 80 7.075 1.075 3.83554568676e-06
# 40 100 10.075 1.075 7.88255498407e-10
# 60 0 -4.925 4.075 2.41129186111e-16
# 60 20 -1.925 4.075 8.8905815168e-14
# 60 40 1.075 4.075 8.95674936303e-13
# 60 60 4.075 4.075 2.4655314111e-13
# 60 80 7.075 4.075 1.85443033682e-15
# 60 100 10.075 4.075 3.81110024178e-19
# 80 0 -4.925 7.075 1.7755482114e-33
# 80 20 -1.925 7.075 6.5465555477e-31
# 80 40 1.075 7.075 6.59527806152e-30
# 80 60 4.075 7.075 1.81548735669e-30
# 80 80 7.075 7.075 1.36550474077e-32
# 80 100 10.075 7.075 2.80629330978e-36
# 100 0 -4.925 10.075 1.99119816714e-58
# 100 20 -1.925 10.075 7.34167020863e-56
# 100 40 1.075 10.075 7.39631033588e-55
# 100 60 4.075 10.075 2.03598813813e-55
# 100 80 7.075 10.075 1.5313526941e-57
# 100 100 10.075 10.075 3.1471328455e-61

# %%
plt.contourf(X,Y,vv,40);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mnorm.pdf([1.2, -1.7])
# Out:
# 0.085653187279569429
